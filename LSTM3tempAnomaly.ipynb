# %% [markdown]
# ###  Practicum #2 - Maggie Sleziak
# ####  Regis University
# ####  LSTM NN
#
# <B>
# <BR>
# <BR>Data set from:
#  https://www.ncdc.noaa.gov/data-access/marineocean-data/noaa-global-surface-temperature-noaaglobaltemp
# <BR>NOAA Merged Land Ocean Global Surface Temperature Analysis (NOAAGlobalTemp)
# <BR>
# <BR>Data: NCEI spatial average time series of monthly data
# <BR>Read the file:
# <BR>From: https://www.ncdc.noaa.gov/data-access/marineocean-data/noaa-global-surface-temperature-noaaglobaltemp
# <BR>
# <BR>Ascii Time Series: ftp://ftp.ncdc.noaa.gov/pub/data/noaaglobaltemp/operational/
# <BR>Monthly and annual land–ocean temperature time series
# <BR>are available from 1880 to present for several zonal bands
# <BR>file name convention for areal average (aravg) time series:
# <BR>ann=annual average
# <BR>mon=monthly average
# <BR>land_ocean=merged land-ocean surface temperature
# <BR>land=land surface temperature for air
# <BR>ocean=ocean surface temperature for water
# <BR>latitudes=southern and northern limits of areal average
# <BR>v=version number
# <BR>yyyymm=date for the latest data
# <BR>
# <BR>Monthly data (aravg.mon.*) :
# <BR>1st column = year
# <BR>2nd column = month
# <BR>3rd column = anomaly of temperature (K)
# <BR>4th column = total error variance (K**2)
# <BR>5th column = high-frequency error variance (K**2)
# <BR>6th column = low-frequency error variance (K**2)
# <BR>7th column = bias error variance (K**2)
# <BR>8th column = diagnostic variable
# <BR>9th column = diagnostic variable
# <BR>10th column= diagnostic variable
# <BR>
#
#
#
# <br>
# <br>Exploration of a univariate problem with lagged data
# Reference:
# <BR>
# <BR>Brownlee, Jason. Machine Learning Mastery with Python: Deep Learning for Time Series Forecasting. Jason Brownlee, 2018.
# <BR>

# %%
# - Load libraries

from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
import pandas as pd
import numpy as np
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt
import matplotlib
from matplotlib import pyplot
import numpy
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
pyplot.rcParams['figure.figsize'] = [10, 5]
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <BR><BR><B>Load and check dataset</B>

# %%
# Start time to time this process: 
startTime = datetime.now()


def parser(x):
	return datetime.strptime(x, '%Y-%m')
series = read_csv('/Users/maggie/Documents/dataScience/practicum2/data/monthlyClean2.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
print(series.head())
# Out:
# YearMonth
# 1880-01-01   -0.239575
# 1880-02-01   -0.376476
# 1880-03-01   -0.395847
# 1880-04-01   -0.296963
# 1880-05-01   -0.309813
# Name: TempAnomaly, dtype: float64

# %%
 
# A plot of the series shows an increasing trend.
print
print('Shape:')
print(series.shape)
print
print('head:')
series.head(10)
print
print('tail:')
series.tail(10)
print

# %matplotlib inline
pyplot.rcParams['figure.figsize'] = [10, 5]
series.plot()
pyplot.show()
# Out:
# <function print>
# Shape:
# (1665,)
# <function print>
# head:
# YearMonth
# 1880-01-01   -0.239575
# 1880-02-01   -0.376476
# 1880-03-01   -0.395847
# 1880-04-01   -0.296963
# 1880-05-01   -0.309813
# 1880-06-01   -0.405013
# 1880-07-01   -0.366857
# 1880-08-01   -0.283096
# 1880-09-01   -0.287228
# 1880-10-01   -0.375328
# Name: TempAnomaly, dtype: float64
# <function print>
# tail:
# YearMonth
# 2017-12-01    0.539903
# 2018-01-01    0.458760
# 2018-02-01    0.423702
# 2018-03-01    0.576104
# 2018-04-01    0.563611
# 2018-05-01    0.547566
# 2018-06-01    0.489483
# 2018-07-01    0.535664
# 2018-08-01    0.515230
# 2018-09-01    0.562892
# Name: TempAnomaly, dtype: float64
# <function print>

# %% [markdown]
# <BR><BR><BR><B>Data Preparation: Transforms</B>

# %%
# Data Preparation
# Before fitting the model, we need to transform the data
# A) Tranform the time series data so it is stationary 
# (mean, variance, autocorrelation, etc. are all constant over time.)
# Here we are adding a lag=1 differencing to remove the increasing trend in the data.
# So the value because the difference between the current value and the value prior to the current value. 

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)


raw_values = series.values
diff_values = difference(raw_values, 1)


print('raw_values:')
print(raw_values.shape)
print(raw_values[:10,])
print

# Now we will have 138 values
print('Stationary:')
print(diff_values.shape)
print(diff_values[:10,])
print

diff_values.plot()
pyplot.show()
# Out:
# raw_values:
# (1665,)
# [-0.239575 -0.376476 -0.395847 -0.296963 -0.309813 -0.405013 -0.366857
#  -0.283096 -0.287228 -0.375328]
# <function print>
# Stationary:
# (1664,)
# 0   -0.136901
# 1   -0.019371
# 2    0.098884
# 3   -0.012850
# 4   -0.095200
# 5    0.038156
# 6    0.083761
# 7   -0.004132
# 8   -0.088100
# 9   -0.094352
# dtype: float64
# <function print>

# %% [markdown]
# <BR><BR><BR><B>Transform to Supervised Problem</B>

# %%
# To Supervised
# B) Transform the time series into a supervised learning problem. 
# Organize data into input and output patterns 
# where the observation at the previous time step is used as an input 
# to forecast the observation at the current timestep
# Using 3 months before to predict current month. 

def timeseries_to_supervised(data, lag=1):
	df = DataFrame(data)
	columns = [df.shift(i) for i in range(1, lag+1)]
	columns.append(df)
	df = concat(columns, axis=1)
	return df

lag = 1 # Or 3 if 3 hours
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, lag)
supervised_values = supervised.values[lag:,:]

print('Stationary:')
print(diff_values.shape)
print(diff_values[:10,])
print

print('Supervised_values:')
print(supervised.shape)
print(supervised_values)
print
# Out:
# Stationary:
# (1664,)
# 0   -0.136901
# 1   -0.019371
# 2    0.098884
# 3   -0.012850
# 4   -0.095200
# 5    0.038156
# 6    0.083761
# 7   -0.004132
# 8   -0.088100
# 9   -0.094352
# dtype: float64
# <function print>
# Supervised_values:
# (1664, 2)
# [[-0.136901 -0.019371]
#  [-0.019371  0.098884]
#  [ 0.098884 -0.01285 ]
#  ...
#  [-0.058083  0.046181]
#  [ 0.046181 -0.020434]
#  [-0.020434  0.047662]]
# <function print>

# %% [markdown]
# <BR><BR><BR><B>Split data into train and test, input, output values</B>

# %%
# Split the data in two parts: training and test set
# The years are 1880-2018. 
# We will use 2/3 or the data (around 1000 months) for training and the remaining for testing
# 

train, test = supervised_values[0:-661], supervised_values[-661:]

print('Train:')
print(train.shape)
print
print
print('Train:')
print(train)
print
print('Test:')
print(test.shape)
print
print
print('Test:')
print(test)
print
# Out:
# Train:
# (1002, 2)
# <function print>
# <function print>
# Train:
# [[-0.136901 -0.019371]
#  [-0.019371  0.098884]
#  [ 0.098884 -0.01285 ]
#  ...
#  [ 0.024553  0.044458]
#  [ 0.044458  0.108484]
#  [ 0.108484  0.022746]]
# <function print>
# Test:
# (661, 2)
# <function print>
# <function print>
# Test:
# [[ 0.022746  0.009894]
#  [ 0.009894  0.059476]
#  [ 0.059476 -0.028413]
#  ...
#  [-0.058083  0.046181]
#  [ 0.046181 -0.020434]
#  [-0.020434  0.047662]]
# <function print>

# %%
# Data Preparation - Continuation
# C) Transform the observations to have a specific scale. Rescale all values to -1 to 1

# scale train and test data to [-1, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(-1, 1))
	scaler = scaler.fit(train)
	# transform train
	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)
	# transform test
	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled

scaler, train_scaled, test_scaled = scale(train, test)

print(scaler)

print('Train:')
print(train_scaled.shape)
print
print
print('Train:')
print(train_scaled)
print
print('Test:')
print(test_scaled.shape)
print
print
print('Test:')
print(test_scaled)
print
# Out:
# MinMaxScaler(copy=True, feature_range=(-1, 1))
# Train:
# (1002, 2)
# <function print>
# <function print>
# Train:
# [[-0.21546181  0.03154466]
#  [ 0.03154466  0.28007482]
#  [ 0.28007482  0.04524949]
#  ...
#  [ 0.12385736  0.16569063]
#  [ 0.16569063  0.30025062]
#  [ 0.30025062  0.12005969]]
# <function print>
# Test:
# (661, 2)
# <function print>
# <function print>
# Test:
# [[ 0.12005969  0.09304933]
#  [ 0.09304933  0.19725315]
#  [ 0.19725315  0.01254157]
#  ...
#  [-0.04981427  0.16931176]
#  [ 0.16931176  0.02931061]
#  [ 0.02931061  0.1724243 ]]
# <function print>

# %%
# Functions to go back to original values for scaled values and for differenced values

# inverse scaling for a forecasted value
def invert_scale(scaler, X, yhat):
	new_row = [x for x in X] + [yhat]
	array = numpy.array(new_row)
	array = array.reshape(1, len(array))
	inverted = scaler.inverse_transform(array)
	return inverted[0, -1]

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# %%
# fit an LSTM network to training data - we need data in 3D (including time here as one of the dimentions)

def fit_model(train, batch_size, nb_epoch, neurons):
	n_hours = 1 # Change to 3 if doing lag 3
	n_features = 1
	X, y = train[:, 0:-1], train[:, -1]
	print(X.shape, y.shape)  
	X = X.reshape((X.shape[0], n_hours, n_features))
	print('Shape after reshape  :')
	print(X.shape, y.shape)

    # Design network
    # Input shape is x (1 or 3) time steps with 1 features for LSTM
	modelLSTM3 = Sequential()
	modelLSTM3.add(LSTM(neurons, input_shape=(X.shape[1], X.shape[2])))
	modelLSTM3.add(Dense(1))

	# Using Mean Absolute Error (MAE) loss function and the efficient Adam version of stochastic gradient descent.
	modelLSTM3.compile(loss='mae', optimizer='adam')
	modelLSTM3.fit(X, y, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False) 
	return modelLSTM3

# %%
# Function to run trail job
def trialjob(repeats, epochs, neurons):
	error_scores = list()
	fit_scores = list()
	n_hours = 1 # Change to 3 if lag is 3 hours
	n_features = 1
	for r in range(repeats):
		# fit the model
		batch_size = 4
		modelLSTM3 = fit_model(train_scaled, batch_size, epochs, neurons)
		# forecast test dataset (X)
		test_X = test_scaled[:,0:-1]
		# print(test_X.shape)  
		test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
		# print('Shape after reshape  :')
		# print(test_X.shape)      
		output = modelLSTM3.predict(test_X, batch_size=batch_size)
		predictions = list()
        
		for i in range(len(output)):
			yhat = output[i,0]
			# print('yhat')
			# print(yhat)
			X = test_scaled[i, 0:-1]
			# print('for X')
			# print(X)
			# invert scaling
			yhat = invert_scale(scaler, X, yhat)
			# print('yhat invert scaling')
			# print(yhat)
			# invert differencing
			yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
			# print('**yhat invert difference')
			# print(yhat)
			# print
			# store forecast
			predictions.append(yhat)
		# report performance
		real_y = raw_values[-661:]
		trainorig_y = raw_values[:1000]
		mse = mean_squared_error(real_y, predictions)
		rmse = sqrt(mean_squared_error(real_y, predictions))
		r2score = r2_score(real_y, predictions)


		print('Test number: %d for: %d neurons, and %d epochs' % (r+1, neurons, epochs))
		print('%d) Test RMSE: %.5f' % (r+1, rmse))
		print('MSE: %.5f' % mse)
		print('Goodness of fit: %.5f' % r2score)
		print  
        
        # Because X (and thus predictions) is one day behind Y. The time series plot look a bit off. 
        # Let's place back the data so we can see the plots better
        # The prediction “prediction” is one index ahead of real output “test_y”.
		plot_y = real_y[:-1]
		plot_predictions = predictions[1:]
      
		pyplot.plot(trainorig_y,color='blue', label = 'Real Y - training set', lw = 0.5, alpha = 0.75)
		pyplot.plot([None for i in trainorig_y] + [x for x in plot_y], color='green', label = 'Real Y test set', lw = 0.5, alpha = 0.75)
		pyplot.plot([None for i in trainorig_y] + [x for x in plot_predictions], color='red', label = 'Prediction for test set',lw = 0.75, alpha = 1)
		pyplot.legend()
		pyplot.show()
        
		pyplot.plot(plot_y[-200:], color='green', label = 'Real Temp at T+1 Count')
		pyplot.plot(plot_predictions[-200:], color='red', label = 'Predicted Temp at T+1 Count')
		pyplot.legend()
		pyplot.show()
		model_mse.append(mse)
		model_rmse.append(rmse)
		model_r2.append(r2score)
		model_epoch.append(epochs)
		model_neuron.append(neurons)
		print()
		print('________________________________________________________________________________')

# %% [markdown]
# <BR><BR><BR><B>Train and fit the model, evaluate results</B>

# %%
# LSTM 
# Epochs - number of forward and backward passes of all training examples
# Batch - number of training examples in a forward/backwards pass
# Interations or repeats = number of passes 

model_epoch = []
model_neuron = []
model_rmse = []
model_r2 = []
model_mse = []

repeats = 5
neurons = 21
# vary training epochs
epochs = [50, 100, 200, 300, 400]

for e in epochs:
	trialjob(repeats, e, neurons)
# Out:
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 1 for: 21 neurons, and 50 epochs
# 1) Test RMSE: 0.09065
# MSE: 0.00822
# Goodness of fit: 0.90541
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 2 for: 21 neurons, and 50 epochs
# 2) Test RMSE: 0.09059
# MSE: 0.00821
# Goodness of fit: 0.90553
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 3 for: 21 neurons, and 50 epochs
# 3) Test RMSE: 0.09057
# MSE: 0.00820
# Goodness of fit: 0.90558
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 4 for: 21 neurons, and 50 epochs
# 4) Test RMSE: 0.09056
# MSE: 0.00820
# Goodness of fit: 0.90559
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 5 for: 21 neurons, and 50 epochs
# 5) Test RMSE: 0.09057
# MSE: 0.00820
# Goodness of fit: 0.90558
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 1 for: 21 neurons, and 100 epochs
# 1) Test RMSE: 0.09061
# MSE: 0.00821
# Goodness of fit: 0.90549
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 2 for: 21 neurons, and 100 epochs
# 2) Test RMSE: 0.09059
# MSE: 0.00821
# Goodness of fit: 0.90554
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 3 for: 21 neurons, and 100 epochs
# 3) Test RMSE: 0.09065
# MSE: 0.00822
# Goodness of fit: 0.90540
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 4 for: 21 neurons, and 100 epochs
# 4) Test RMSE: 0.09060
# MSE: 0.00821
# Goodness of fit: 0.90552
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 5 for: 21 neurons, and 100 epochs
# 5) Test RMSE: 0.09062
# MSE: 0.00821
# Goodness of fit: 0.90547
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 1 for: 21 neurons, and 200 epochs
# 1) Test RMSE: 0.09067
# MSE: 0.00822
# Goodness of fit: 0.90537
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 2 for: 21 neurons, and 200 epochs
# 2) Test RMSE: 0.09063
# MSE: 0.00821
# Goodness of fit: 0.90544
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 3 for: 21 neurons, and 200 epochs
# 3) Test RMSE: 0.09066
# MSE: 0.00822
# Goodness of fit: 0.90539
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 4 for: 21 neurons, and 200 epochs
# 4) Test RMSE: 0.09065
# MSE: 0.00822
# Goodness of fit: 0.90542
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 5 for: 21 neurons, and 200 epochs
# 5) Test RMSE: 0.09068
# MSE: 0.00822
# Goodness of fit: 0.90534
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 1 for: 21 neurons, and 300 epochs
# 1) Test RMSE: 0.09056
# MSE: 0.00820
# Goodness of fit: 0.90560
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 2 for: 21 neurons, and 300 epochs
# 2) Test RMSE: 0.09056
# MSE: 0.00820
# Goodness of fit: 0.90560
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 3 for: 21 neurons, and 300 epochs
# 3) Test RMSE: 0.09069
# MSE: 0.00822
# Goodness of fit: 0.90532
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 4 for: 21 neurons, and 300 epochs
# 4) Test RMSE: 0.09067
# MSE: 0.00822
# Goodness of fit: 0.90536
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 5 for: 21 neurons, and 300 epochs
# 5) Test RMSE: 0.09049
# MSE: 0.00819
# Goodness of fit: 0.90574
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 1 for: 21 neurons, and 400 epochs
# 1) Test RMSE: 0.09032
# MSE: 0.00816
# Goodness of fit: 0.90609
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 2 for: 21 neurons, and 400 epochs
# 2) Test RMSE: 0.09041
# MSE: 0.00817
# Goodness of fit: 0.90590
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 3 for: 21 neurons, and 400 epochs
# 3) Test RMSE: 0.09036
# MSE: 0.00817
# Goodness of fit: 0.90600
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 4 for: 21 neurons, and 400 epochs
# 4) Test RMSE: 0.09036
# MSE: 0.00816
# Goodness of fit: 0.90601
# ________________________________________________________________________________
# (1002, 1) (1002,)
# Shape after reshape  :
# (1002, 1, 1) (1002,)
# Test number: 5 for: 21 neurons, and 400 epochs
# 5) Test RMSE: 0.09033
# MSE: 0.00816
# Goodness of fit: 0.90608
# ________________________________________________________________________________

# %%
predictionSummary = pd.DataFrame({
                                  'Epochs':np.array(model_epoch),
                                  'Neurons':np.array(model_neuron),
                                  'R2':np.array(model_r2),
                                  'RMSE':np.array(model_rmse),
                                  'MSE':np.array(model_mse),})
                                  

print('LSTM Lag1 Results - Sorted by R2 (Coefficient Of Determination - Goodness of fit) :')
print()
print(predictionSummary.sort_values(by=['R2'], ascending=False)) 
print()
print(predictionSummary.describe())
# Out:
# LSTM Lag1 Results - Sorted by R2 (Coefficient Of Determination - Goodness of fit) :
#
#     Epochs  Neurons        R2      RMSE       MSE
# 20     400       21  0.906089  0.090322  0.008158
# 24     400       21  0.906081  0.090326  0.008159
# 23     400       21  0.906013  0.090359  0.008165
# 22     400       21  0.906003  0.090364  0.008166
# 21     400       21  0.905898  0.090414  0.008175
# 19     300       21  0.905737  0.090491  0.008189
# 16     300       21  0.905599  0.090557  0.008201
# 15     300       21  0.905598  0.090558  0.008201
# 3       50       21  0.905589  0.090563  0.008202
# 2       50       21  0.905580  0.090567  0.008202
# 4       50       21  0.905578  0.090568  0.008203
# 6      100       21  0.905542  0.090585  0.008206
# 1       50       21  0.905533  0.090589  0.008206
# 8      100       21  0.905520  0.090596  0.008208
# 5      100       21  0.905495  0.090608  0.008210
# 9      100       21  0.905466  0.090621  0.008212
# 11     200       21  0.905443  0.090633  0.008214
# 13     200       21  0.905416  0.090646  0.008217
# 0       50       21  0.905412  0.090647  0.008217
# 7      100       21  0.905400  0.090653  0.008218
# 12     200       21  0.905394  0.090656  0.008218
# 10     200       21  0.905366  0.090669  0.008221
# 18     300       21  0.905364  0.090670  0.008221
# 14     200       21  0.905338  0.090683  0.008223
# 17     300       21  0.905321  0.090691  0.008225
#
#            Epochs  Neurons         R2       RMSE        MSE
# count   25.000000     25.0  25.000000  25.000000  25.000000
# mean   210.000000     21.0   0.905591   0.090561   0.008201
# std    130.703226      0.0   0.000240   0.000115   0.000021
# min     50.000000     21.0   0.905321   0.090322   0.008158
# 25%    100.000000     21.0   0.905412   0.090557   0.008201
# 50%    200.000000     21.0   0.905533   0.090589   0.008206
# 75%    300.000000     21.0   0.905599   0.090647   0.008217
# max    400.000000     21.0   0.906089   0.090691   0.008225

# %%
predictionSummary.to_csv('./data/LSTMSummary.csv')
# Get the time: 
print(datetime.now() - startTime)
# Out:
# 0:52:13.166228
